# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, MultiHeadAttention, Dropout, LayerNormalization, GlobalAveragePooling1D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam

import os
import numpy as np
import pandas as pd
from backtesting import Backtest, Strategy
from bokeh.io import show, output_notebook, save

import os
from joblib import load
from tensorflow.keras.models import load_model
from pathlib import Path

import os
from joblib import dump
from tensorflow.keras.models import save_model
from pathlib import Path

import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os

# File paths for saving results
RESULT_DATA_DIR = os.path.join("data", "result-data")
os.makedirs(RESULT_DATA_DIR, exist_ok=True)

# %%
# 1. Silence logs
import os


# Set environment variables to suppress logs
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"                         # Only show errors from TF C++ backend
os.environ["TF_CPP_MIN_VLOG_LEVEL"] = "3"                          # Increase VLOG level to filter out debug info (try "99" if needed)
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"                          # Avoid verbose ONEDNN CPU messages
os.environ["TF_TRT_ALLOW_ENGINE_NATIVE_SEGMENT_EXECUTION"] = "false"  # Silence TF-TRT warnings
os.environ["GRPC_VERBOSITY"] = "ERROR"                           # Silence gRPC logs
os.environ["GRPC_CPP_LOG_LEVEL"] = "ERROR"


from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

# 2. Set visible GPU devices BEFORE importing TensorFlow
import sys

# Optional: Use only first GPU
USE_ONLY_GPU_INDEX = 0

# Import TensorFlow config module ONLY (not the full library yet!)
from tensorflow.python.framework import config as tf_config
from tensorflow.python.eager import context as tf_context

# List GPUs (from lower-level API)
physical_devices = tf_config.list_physical_devices('GPU')
if physical_devices:
    try:
        # Optional: use only the first GPU
        tf_config.set_visible_devices(physical_devices[USE_ONLY_GPU_INDEX], 'GPU')

        # Enable memory growth
        tf_config.set_memory_growth(physical_devices[USE_ONLY_GPU_INDEX], True)

    except RuntimeError as e:
        print("GPU config error:", e)
else:
    raise RuntimeError("No GPU found!")

# 3. Now it's safe to import TensorFlow proper
import tensorflow as tf

# 4. Silence warnings if needed
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

# Optional: verify
print("GPUs available:", tf.config.list_logical_devices('GPU'))
# Out:
# GPUs available: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
import os
import pandas as pd

# Define the directory containing processed data files
PROCESSED_DATA = os.path.join("data", "processed-data")

# File paths for processed data
# btc_processed_file = os.path.join(PROCESSED_DATA, "btc_1min_processed.csv.gz")
# eth_processed_file = os.path.join(PROCESSED_DATA, "eth_1min_processed.csv.gz")
# combined_file = os.path.join(PROCESSED_DATA, "crypto_1min_combined.csv.gz")
# NEWS_FILTERED_CSV = os.path.join(PROCESSED_DATA, "aggregated-news_filtered.csv.gz")

# File paths for data with features
btc_features_file = os.path.join(PROCESSED_DATA, "btc_1min_with_features.csv.gz")
eth_features_file = os.path.join(PROCESSED_DATA, "eth_1min_with_features.csv.gz")

# File paths for targets
btc_target_file = os.path.join(PROCESSED_DATA, "btc_1min_targets.csv.gz")
eth_target_file = os.path.join(PROCESSED_DATA, "eth_1min_targets.csv.gz")

# Load processed data
# btc_df = pd.read_csv(btc_processed_file, compression="gzip")
# eth_df = pd.read_csv(eth_processed_file, compression="gzip")
# crypto_df = pd.read_csv(combined_file, compression="gzip")
# df_filtered_news = pd.read_csv(NEWS_FILTERED_CSV, compression="gzip")

# Load feature data
btc_df_features = pd.read_csv(btc_features_file, compression="gzip")
eth_df_features = pd.read_csv(eth_features_file, compression="gzip")

# Load target data
btc_targets = pd.read_csv(btc_target_file, compression="gzip")
eth_targets = pd.read_csv(eth_target_file, compression="gzip")

# %%
# %%
# Utility: Create directories
def setup_directories():
    os.makedirs("plots", exist_ok=True)
    os.makedirs("models", exist_ok=True)
    os.makedirs("logs", exist_ok=True)
    return "Done"

# %%
# Prepares merged dataset of features + targets and subsets by percentage
def get_data_subset(features_df, targets_df, target_col, data_percent=0.01):
    merged = pd.concat([features_df, targets_df], axis=1)
    subset_size = int(len(merged) * data_percent)
    subset = merged.iloc[:subset_size].copy()
    X = subset.drop(columns=[target_col])
    y = subset[target_col]
    return X, y, subset

# %%
# Normalize features using MinMaxScaler
def scale_features(X):
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled, scaler

# %%
# Convert time-series data into sequences
def create_sequences(X, y, time_steps=30):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i : i + time_steps])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
# Time-based train/test split
def train_test_split_sequences(X_seq, y_seq, train_ratio=0.8):
    train_size = int(len(X_seq) * train_ratio)
    X_train, y_train = X_seq[:train_size], y_seq[:train_size]
    X_test, y_test = X_seq[train_size:], y_seq[train_size:]
    return X_train, y_train, X_test, y_test

# %%
# Build GRU model (easily replaceable with CNN/Transformer later)
def build_gru_model(input_shape):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import GRU, Dropout, Dense
    from tensorflow.keras.optimizers import Adam

    model = Sequential()
    model.add(GRU(64, activation='tanh', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
    return model

def format_percent_string(p):
    return f"{p * 100:.4f}".rstrip("0").rstrip(".").replace(".", "_")


# %%
# Train model with checkpointing and logging
def train_model(model, X_train, y_train, X_val, y_val, data_percent=0.01, epochs=20):
    
    percent_display = format_percent_string(data_percent)

    model_name = f"gru_btc_model_{percent_display}pct.h5"
    log_name = f"gru_btc_log_{percent_display}pct.csv"

    checkpoint = ModelCheckpoint(os.path.join("models", model_name), monitor="val_loss", save_best_only=True, verbose=1)
    early_stop = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True, verbose=1)
    csv_logger = CSVLogger(os.path.join("logs", log_name))

    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=32,
        validation_data=(X_val, y_val),
        callbacks=[checkpoint, early_stop, csv_logger],
        verbose=1
    )
    return history


# %%
# Evaluate performance
def print_metrics(y_test, y_pred, data_percent=0.01):
    from sklearn.metrics import mean_squared_error, mean_absolute_error
    import numpy as np

    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)

    print(f"Metrics for {data_percent*100:.3f}% dataset:")
    print(f"MSE:  {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE:  {mae:.4f}")

# %%
import os
import numpy as np
import pandas as pd

# %%
DATA_PERCENT = 0.001
TIME_STEPS = 30
TARGET_COL = "btc_Close_1m_later"

# %%
setup_directories()
# Out:
# 'Done'

# %%
X_raw, y_raw, btc_subset = get_data_subset(btc_df_features, btc_targets, TARGET_COL, DATA_PERCENT)

# %%
X_scaled, scaler = scale_features(X_raw)

# %%
X_seq, y_seq = create_sequences(X_scaled, y_raw.values, TIME_STEPS)

# %%
X_train, y_train, X_test, y_test = train_test_split_sequences(X_seq, y_seq)

# %%
model = build_gru_model(input_shape=(X_train.shape[1], X_train.shape[2]))

# %%
history = train_model(model, X_train, y_train, X_test, y_test, DATA_PERCENT)
# Out:
# Epoch 1/20
# 144/157 [==========================>...] - ETA: 0s - loss: 1.8491
# Epoch 1: val_loss improved from inf to 0.01303, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 3s 6ms/step - loss: 1.7185 - val_loss: 0.0130
# Epoch 2/20
# 147/157 [===========================>..] - ETA: 0s - loss: 0.1714
# Epoch 2: val_loss improved from 0.01303 to 0.00642, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1705 - val_loss: 0.0064
# Epoch 3/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1486
# Epoch 3: val_loss improved from 0.00642 to 0.00642, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1465 - val_loss: 0.0064
# Epoch 4/20
# 146/157 [==========================>...] - ETA: 0s - loss: 0.1355
# Epoch 4: val_loss did not improve from 0.00642
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1359 - val_loss: 0.0074
# Epoch 5/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1291
# Epoch 5: val_loss did not improve from 0.00642
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1297 - val_loss: 0.0188
# Epoch 6/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1322
# Epoch 6: val_loss did not improve from 0.00642
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1328 - val_loss: 0.0238
# Epoch 7/20
# 147/157 [===========================>..] - ETA: 0s - loss: 0.1186
# Epoch 7: val_loss improved from 0.00642 to 0.00435, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1182 - val_loss: 0.0043
# Epoch 8/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1233
# Epoch 8: val_loss did not improve from 0.00435
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1243 - val_loss: 0.0100
# Epoch 9/20
# 150/157 [===========================>..] - ETA: 0s - loss: 0.1187
# Epoch 9: val_loss improved from 0.00435 to 0.00304, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1192 - val_loss: 0.0030
# Epoch 10/20
# 150/157 [===========================>..] - ETA: 0s - loss: 0.1153
# Epoch 10: val_loss improved from 0.00304 to 0.00300, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1149 - val_loss: 0.0030
# Epoch 11/20
# 146/157 [==========================>...] - ETA: 0s - loss: 0.1159
# Epoch 11: val_loss improved from 0.00300 to 0.00294, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1156 - val_loss: 0.0029
# Epoch 12/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1164
# Epoch 12: val_loss did not improve from 0.00294
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1157 - val_loss: 0.0036
# Epoch 13/20
# 146/157 [==========================>...] - ETA: 0s - loss: 0.1144
# Epoch 13: val_loss did not improve from 0.00294
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1133 - val_loss: 0.0134
# Epoch 14/20
# 147/157 [===========================>..] - ETA: 0s - loss: 0.1144
# Epoch 14: val_loss did not improve from 0.00294
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1144 - val_loss: 0.0041
# Epoch 15/20
# 147/157 [===========================>..] - ETA: 0s - loss: 0.1129
# Epoch 15: val_loss did not improve from 0.00294
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1117 - val_loss: 0.0089
# Epoch 16/20
# 147/157 [===========================>..] - ETA: 0s - loss: 0.1113
# Epoch 16: val_loss did not improve from 0.00294
# Restoring model weights from the end of the best epoch: 11.
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1106 - val_loss: 0.0051
# Epoch 16: early stopping

# %%
def plot_loss(history, plots_dir="plots", data_percent=0.01, model_name="gru", dataset_name="btc"):
    import os
    import matplotlib.pyplot as plt

    # Ensure directory exists
    os.makedirs(plots_dir, exist_ok=True)

    # Format percent strings
    percent_display_filename = format_percent_string(data_percent)  # for file name
    percent_display_title = f"{data_percent * 100:.2f}"            # for title

    # Plot
    plt.figure(figsize=(10, 4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f"Loss Curve ({percent_display_title}% Data)")
    plt.xlabel("Epoch")
    plt.ylabel("MSE")
    plt.legend()
    plt.grid(True)

    # Save to file inside plots directory
    filename = f"loss_curve_{model_name}_{dataset_name}_{percent_display_filename}pct.png"
    loss_curve_path = os.path.join(plots_dir, filename)
    plt.savefig(loss_curve_path)
    plt.show()
    print(f"Loss curve saved to: {loss_curve_path}")

# %%
plot_loss(history, data_percent=DATA_PERCENT, model_name="gru", dataset_name="btc")
# Out:
# Loss curve saved to: plots/loss_curve_gru_btc_0_1pct.png

# %%
y_pred = model.predict(X_test)
# Out:
# 40/40 [==============================] - 0s 1ms/step

# %%
def plot_predictions(y_test, y_pred, plots_dir="plots", data_percent=0.01, model_name="gru", dataset_name="btc", last_n=200):


    # Ensure plots directory exists
    os.makedirs(plots_dir, exist_ok=True)

    # Format percent strings
    percent_display_filename = format_percent_string(data_percent)  # for file name
    percent_display_title = f"{data_percent * 100:.2f}"            # for plot title

    # Build comparison DataFrame
    comparison_df = pd.DataFrame({
        "Actual": y_test,
        "Predicted": y_pred.flatten()
    })

    # Plot predictions
    plt.figure(figsize=(10, 4))
    plt.plot(comparison_df["Actual"][-last_n:], label="Actual")
    plt.plot(comparison_df["Predicted"][-last_n:], label="Predicted", linestyle="--")
    plt.title(f"{dataset_name.upper()} Close Price Prediction (Last {last_n} Samples) - {percent_display_title}% Data")
    plt.xlabel("Time Step")
    plt.ylabel("Close Price")
    plt.legend()
    plt.grid(True)

    # Save plot
    filename = f"prediction_plot_{model_name}_{dataset_name}_{percent_display_filename}pct.png"
    plot_path = os.path.join(plots_dir, filename)
    plt.savefig(plot_path)
    print(f"Prediction plot saved to: {plot_path}")
    plt.show()

    # Save DataFrame comparison to CSV
    result_file = os.path.join(RESULT_DATA_DIR, f"{dataset_name}_comparison_{percent_display_filename}pct.csv")
    comparison_df.to_csv(result_file, index=False)

    print(f"Comparison CSV saved to: {result_file}")
    return comparison_df

# %%
comparison_df = plot_predictions(y_test, y_pred, data_percent=DATA_PERCENT, model_name="gru", dataset_name="btc")
# Out:
# Prediction plot saved to: plots/prediction_plot_gru_btc_0_1pct.png
# Comparison CSV saved to: data/result-data/btc_comparison_0_1pct.csv

# %%
print_metrics(y_test, y_pred, DATA_PERCENT)
# Out:
# Metrics for 0.100% dataset:
# MSE:  0.0029
# RMSE: 0.0542
# MAE:  0.0383

# %%
def save_model_and_scaler(model, scaler, model_name: str, dataset_name: str, data_percent: float, model_ext: str = "h5"):
    os.makedirs("models", exist_ok=True)

    # Format percent with up to 4 decimal places, replace dot with underscore
    percent_str = f"{data_percent * 100:.4f}".rstrip("0").rstrip(".").replace(".", "_")

    model_filename = f"{model_name}_{dataset_name}_model_{percent_str}pct.{model_ext}"
    scaler_filename = f"scaler_{dataset_name}_{percent_str}pct.pkl"

    model_path = Path("models") / model_filename
    scaler_path = Path("models") / scaler_filename

    if model_ext in ['h5', 'keras']:
        save_model(model, str(model_path))
    else:
        dump(model, model_path)

    dump(scaler, scaler_path)

    print("Model saved to:", model_path.resolve().relative_to(Path.cwd()))
    print("Scaler saved to:", scaler_path.resolve().relative_to(Path.cwd()))

# %%
save_model_and_scaler(model, scaler, model_name="gru", dataset_name="btc", data_percent=DATA_PERCENT)
# Out:
# Model saved to: models/gru_btc_model_0_1pct.h5
# Scaler saved to: models/scaler_btc_0_1pct.pkl

# %%
def load_model_and_scaler(model_name: str, dataset_name: str, data_percent: float, model_ext: str = "h5"):
    # Format percent with full decimals and replace '.' with '_'
    percent_str = f"{data_percent * 100:.4f}".rstrip("0").rstrip(".").replace(".", "_")

    model_filename = f"{model_name}_{dataset_name}_model_{percent_str}pct.{model_ext}"
    scaler_filename = f"scaler_{dataset_name}_{percent_str}pct.pkl"

    model_path = Path("models") / model_filename
    scaler_path = Path("models") / scaler_filename

    if model_ext in ['h5', 'keras']:
        model = load_model(model_path)
    else:
        model = load(model_path)

    scaler = load(scaler_path)

    print("Model loaded from:", model_path.resolve().relative_to(Path.cwd()))
    print("Scaler loaded from:", scaler_path.resolve().relative_to(Path.cwd()))

    return model, scaler

# %%
model, scaler = load_model_and_scaler(model_name="gru", dataset_name="btc", data_percent=DATA_PERCENT)
# Out:
# Model loaded from: models/gru_btc_model_0_1pct.h5
# Scaler loaded from: models/scaler_btc_0_1pct.pkl

# %%
output_notebook()

def prepare_backtest_data(y_test, y_pred, time_index):
    df = pd.DataFrame({
        "Open": np.array(y_test).flatten(),
        "High": np.array(y_test).flatten(),
        "Low": np.array(y_test).flatten(),
        "Close": np.array(y_test).flatten(),
        "Signal": np.where(np.array(y_pred).flatten() > np.array(y_test).flatten(), 1, -1)
    })
    df.index = time_index
    return df

class MLStrategy(Strategy):
    def init(self):
        self.signal = self.data.Signal
    def next(self):
        if self.signal[-1] == 1:
            if not self.position.is_long:
                self.position.close()
                self.buy()
        elif self.signal[-1] == -1:
            if not self.position.is_short:
                self.position.close()
                self.sell()

def run_backtest(y_test, y_pred, initial_cash=100, model_name="gru", dataset_name="btc", data_percent=0.01):
    time_index = y_test.index if hasattr(y_test, 'index') else pd.date_range(
        start='2022-01-01', periods=len(np.array(y_test).flatten()), freq='T')
    
    data = prepare_backtest_data(y_test, y_pred, time_index)
    bt = Backtest(data, MLStrategy, cash=initial_cash, commission=0.0, exclusive_orders=True)
    stats = bt.run()
    print(stats)
    
    # Create a results directory based on model info.
    percent_str = f"{data_percent*100:.4f}".rstrip("0").rstrip(".").replace(".", "_")
    result_dir = os.path.join("results", f"{model_name}_{dataset_name}_{percent_str}pct")
    os.makedirs(result_dir, exist_ok=True)
    
    # Save backtest statistics as CSV.
    csv_filename = os.path.join(result_dir, "backtest_result.csv")
    stats.to_csv(csv_filename)
    
    # Generate the plot, save it as HTML, and display it in Jupyter.
    plot_obj = bt.plot()
    html_filename = os.path.join(result_dir, "backtest_plot.html")
    save(plot_obj, filename=html_filename)    
    return stats

# Example usage:
stats = run_backtest(y_test, y_pred, initial_cash=100, model_name="gru", dataset_name="btc", data_percent=DATA_PERCENT)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fa4a4df0-0cc8-45c5-a6d1-562400255181">Loading BokehJS ...</span>
#     </div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dde91f37-5015-40e2-859f-924748cdeb6d">Loading BokehJS ...</span>
#     </div>
# Backtest.run:   0%|          | 0/1250 [00:00<?, ?bar/s]
# Start                     2022-01-01 00:00:00
# End                       2022-01-01 20:50:00
# Duration                      0 days 20:50:00
# Exposure Time [%]                         0.0
# Equity Final [$]                       110.98
# Equity Peak [$]                        115.12
# Return [%]                              10.98
# Buy & Hold Return [%]               -11.33829
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# CAGR [%]                  1058035078373143...
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              0.0
# Alpha [%]                              1.7785
# Beta                                 -0.81154
# Max. Drawdown [%]                     -5.9166
# Avg. Drawdown [%]                    -2.58323
# Max. Drawdown Duration        0 days 02:28:00
# Avg. Drawdown Duration        0 days 00:49:00
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# Kelly Criterion                           NaN
# _strategy                          MLStrategy
# _equity_curve                             ...
# _trades                   Empty DataFrame
# ...
# dtype: object
#   <div id="d1f30aa6-7f00-43f0-a829-77c9d2cc1e21" data-root-id="p1109" style="display: contents;"></div>

# %%
def build_model_by_type(model_type, input_shape):
    model_type = model_type.lower()
    if model_type == "gru":
        return build_gru_model(input_shape)
    elif model_type == "cnn":
        return build_cnn_model(input_shape)
    elif model_type == "transformer":
        return build_transformer_model(input_shape)
    elif model_type == "rnn":
        return build_rnn_model(input_shape)
    else:
        raise ValueError("Unsupported model type. Choose from 'gru', 'cnn', 'transformer', or 'rnn'.")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
def run_full_pipeline(asset, model_type, data_percent, epochs=20, time_steps=30, initial_cash=100):
    print("Setting up directories...")
    setup_directories()
    
    print(f"Loading data for asset: {asset}")
    if asset.lower() == "btc":
        features_df = btc_df_features
        targets_df = btc_targets
        target_col = "btc_Close_1m_later"
    elif asset.lower() == "eth":
        features_df = eth_df_features
        targets_df = eth_targets
        target_col = "eth_Close_1m_later"
    else:
        raise ValueError("Asset must be either 'btc' or 'eth'")
    
    print("Subsetting data...")
    X_raw, y_raw, _ = get_data_subset(features_df, targets_df, target_col, data_percent)
    
    print("Normalizing features...")
    X_scaled, scaler = scale_features(X_raw)
    
    print("Creating sequences...")
    X_seq, y_seq = create_sequences(X_scaled, y_raw.values, time_steps)
    
    print("Splitting data into training and testing sets...")
    X_train, y_train, X_test, y_test = train_test_split_sequences(X_seq, y_seq)
    
    print("Building model...")
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_model_by_type(model_type, input_shape)
    
    print("Training model...")
    history = train_model(model, X_train, y_train, X_test, y_test, data_percent, epochs)
    
    print("Plotting training loss...")
    plot_loss(history, data_percent=data_percent, model_name=model_type, dataset_name=asset)
    
    print("Generating predictions...")
    y_pred = model.predict(X_test)
    
    print("Plotting predictions and saving comparison CSV...")
    comparison_df = plot_predictions(y_test, y_pred, data_percent=data_percent, model_name=model_type, dataset_name=asset)
    
    print("Printing evaluation metrics...")
    print_metrics(y_test, y_pred, data_percent)
    
    print("Saving model and scaler...")
    save_model_and_scaler(model, scaler, model_name=model_type, dataset_name=asset, data_percent=data_percent)
    
    print("Running backtesting...")
    stats = run_backtest(y_test, y_pred, initial_cash=initial_cash, model_name=model_type, dataset_name=asset, data_percent=data_percent)
    
    print("Pipeline complete.")
    return stats

# %%
stats_btc_gru = run_full_pipeline(asset="btc", model_type="gru", data_percent=1)
# Out:
# Setting up directories...
# Loading data for asset: btc
# Subsetting data...
# Normalizing features...
# Creating sequences...
# Splitting data into training and testing sets...
# Building model...
# Training model...
# Epoch 1/20
# 143/157 [==========================>...] - ETA: 0s - loss: 1.3445
# Epoch 1: val_loss improved from inf to 0.01472, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 2s 6ms/step - loss: 1.2467 - val_loss: 0.0147
# Epoch 2/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1849
# Epoch 2: val_loss improved from 0.01472 to 0.01047, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1855 - val_loss: 0.0105
# Epoch 3/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1603
# Epoch 3: val_loss improved from 0.01047 to 0.00859, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1594 - val_loss: 0.0086
# Epoch 4/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1419
# Epoch 4: val_loss improved from 0.00859 to 0.00617, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1432 - val_loss: 0.0062
# Epoch 5/20
# 144/157 [==========================>...] - ETA: 0s - loss: 0.1379
# Epoch 5: val_loss did not improve from 0.00617
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1391 - val_loss: 0.0103
# Epoch 6/20
# 140/157 [=========================>....] - ETA: 0s - loss: 0.1293
# Epoch 6: val_loss improved from 0.00617 to 0.00398, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1275 - val_loss: 0.0040
# Epoch 7/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1233
# Epoch 7: val_loss did not improve from 0.00398
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1215 - val_loss: 0.0042
# Epoch 8/20
# 144/157 [==========================>...] - ETA: 0s - loss: 0.1215
# Epoch 8: val_loss improved from 0.00398 to 0.00386, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1213 - val_loss: 0.0039
# Epoch 9/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1175
# Epoch 9: val_loss did not improve from 0.00386
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1167 - val_loss: 0.0041
# Epoch 10/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1182
# Epoch 10: val_loss did not improve from 0.00386
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1187 - val_loss: 0.0069
# Epoch 11/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1164
# Epoch 11: val_loss improved from 0.00386 to 0.00270, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1160 - val_loss: 0.0027
# Epoch 12/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1133
# Epoch 12: val_loss did not improve from 0.00270
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1132 - val_loss: 0.0266
# Epoch 13/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1189
# Epoch 13: val_loss did not improve from 0.00270
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1181 - val_loss: 0.0052
# Epoch 14/20
# 144/157 [==========================>...] - ETA: 0s - loss: 0.1117
# Epoch 14: val_loss did not improve from 0.00270
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1122 - val_loss: 0.0048
# Epoch 15/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.1129
# Epoch 15: val_loss did not improve from 0.00270
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1142 - val_loss: 0.0056
# Epoch 16/20
# 146/157 [==========================>...] - ETA: 0s - loss: 0.1110
# Epoch 16: val_loss did not improve from 0.00270
# Restoring model weights from the end of the best epoch: 11.
# 157/157 [==============================] - 1s 3ms/step - loss: 0.1100 - val_loss: 0.0086
# Epoch 16: early stopping
# Plotting training loss...
# Loss curve saved to: plots/loss_curve_gru_btc_0_1pct.png
# Generating predictions...
# 40/40 [==============================] - 0s 1ms/step
# Plotting predictions and saving comparison CSV...
# Prediction plot saved to: plots/prediction_plot_gru_btc_0_1pct.png
# Comparison CSV saved to: data/result-data/btc_comparison_0_1pct.csv
# Printing evaluation metrics...
# Metrics for 0.100% dataset:
# MSE:  0.0027
# RMSE: 0.0520
# MAE:  0.0313
# Saving model and scaler...
# Model saved to: models/gru_btc_model_0_1pct.h5
# Scaler saved to: models/scaler_btc_0_1pct.pkl
# Running backtesting...
# Backtest.run:   0%|          | 0/1250 [00:00<?, ?bar/s]
# Start                     2022-01-01 00:00:00
# End                       2022-01-01 20:50:00
# Duration                      0 days 20:50:00
# Exposure Time [%]                         0.0
# Equity Final [$]                       110.98
# Equity Peak [$]                        115.12
# Return [%]                              10.98
# Buy & Hold Return [%]               -11.33829
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# CAGR [%]                  1058035078373143...
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              0.0
# Alpha [%]                              1.7785
# Beta                                 -0.81154
# Max. Drawdown [%]                     -5.9166
# Avg. Drawdown [%]                    -2.58323
# Max. Drawdown Duration        0 days 02:28:00
# Avg. Drawdown Duration        0 days 00:49:00
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# Kelly Criterion                           NaN
# _strategy                          MLStrategy
# _equity_curve                             ...
# _trades                   Empty DataFrame
# ...
# dtype: object
#   <div id="ffb645a8-6f61-408b-861d-4bc19fc649b8" data-root-id="p1251" style="display: contents;"></div>
# Pipeline complete.

# %% [markdown]
# ## CNN

# %%
def build_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
    return model

# %%
stats_btc_cnn = run_full_pipeline(asset="btc", model_type="cnn", data_percent=0.001)
# Out:
# Setting up directories...
# Loading data for asset: btc
# Subsetting data...
# Normalizing features...
# Creating sequences...
# Splitting data into training and testing sets...
# Building model...
# Training model...
# Epoch 1/20
# 157/157 [==============================] - ETA: 0s - loss: 0.7656
# Epoch 1: val_loss improved from inf to 0.02704, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 3s 5ms/step - loss: 0.7656 - val_loss: 0.0270
# Epoch 2/20
# 148/157 [===========================>..] - ETA: 0s - loss: 0.1095
# Epoch 2: val_loss improved from 0.02704 to 0.02067, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1080 - val_loss: 0.0207
# Epoch 3/20
# 148/157 [===========================>..] - ETA: 0s - loss: 0.0801
# Epoch 3: val_loss improved from 0.02067 to 0.01985, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0825 - val_loss: 0.0198
# Epoch 4/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0684
# Epoch 4: val_loss improved from 0.01985 to 0.01471, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0686 - val_loss: 0.0147
# Epoch 5/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0622
# Epoch 5: val_loss did not improve from 0.01471
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0630 - val_loss: 0.0531
# Epoch 6/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0579
# Epoch 6: val_loss improved from 0.01471 to 0.01095, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0572 - val_loss: 0.0110
# Epoch 7/20
# 150/157 [===========================>..] - ETA: 0s - loss: 0.0568
# Epoch 7: val_loss improved from 0.01095 to 0.00949, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0566 - val_loss: 0.0095
# Epoch 8/20
# 150/157 [===========================>..] - ETA: 0s - loss: 0.0537
# Epoch 8: val_loss did not improve from 0.00949
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0534 - val_loss: 0.0225
# Epoch 9/20
# 147/157 [===========================>..] - ETA: 0s - loss: 0.0523
# Epoch 9: val_loss did not improve from 0.00949
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0527 - val_loss: 0.0343
# Epoch 10/20
# 143/157 [==========================>...] - ETA: 0s - loss: 0.0516
# Epoch 10: val_loss did not improve from 0.00949
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0514 - val_loss: 0.0371
# Epoch 11/20
# 145/157 [==========================>...] - ETA: 0s - loss: 0.0583
# Epoch 11: val_loss did not improve from 0.00949
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0571 - val_loss: 0.0103
# Epoch 12/20
# 147/157 [===========================>..] - ETA: 0s - loss: 0.0504
# Epoch 12: val_loss improved from 0.00949 to 0.00687, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0505 - val_loss: 0.0069
# Epoch 13/20
# 148/157 [===========================>..] - ETA: 0s - loss: 0.0467
# Epoch 13: val_loss did not improve from 0.00687
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0466 - val_loss: 0.0227
# Epoch 14/20
# 146/157 [==========================>...] - ETA: 0s - loss: 0.0484
# Epoch 14: val_loss did not improve from 0.00687
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0491 - val_loss: 0.0439
# Epoch 15/20
# 143/157 [==========================>...] - ETA: 0s - loss: 0.0504
# Epoch 15: val_loss did not improve from 0.00687
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0506 - val_loss: 0.0111
# Epoch 16/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0494
# Epoch 16: val_loss did not improve from 0.00687
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0494 - val_loss: 0.0091
# Epoch 17/20
# 149/157 [===========================>..] - ETA: 0s - loss: 0.0465
# Epoch 17: val_loss did not improve from 0.00687
# Restoring model weights from the end of the best epoch: 12.
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0471 - val_loss: 0.1025
# Epoch 17: early stopping
# Plotting training loss...
# Loss curve saved to: plots/loss_curve_cnn_btc_0_1pct.png
# Generating predictions...
# 40/40 [==============================] - 0s 944us/step
# Plotting predictions and saving comparison CSV...
# Prediction plot saved to: plots/prediction_plot_cnn_btc_0_1pct.png
# Comparison CSV saved to: data/result-data/btc_comparison_0_1pct.csv
# Printing evaluation metrics...
# Metrics for 0.100% dataset:
# MSE:  0.0069
# RMSE: 0.0829
# MAE:  0.0642
# Saving model and scaler...
# Model saved to: models/cnn_btc_model_0_1pct.h5
# Scaler saved to: models/scaler_btc_0_1pct.pkl
# Running backtesting...
# Backtest.run:   0%|          | 0/1250 [00:00<?, ?bar/s]
# Start                     2022-01-01 00:00:00
# End                       2022-01-01 20:50:00
# Duration                      0 days 20:50:00
# Exposure Time [%]                         0.0
# Equity Final [$]                       110.98
# Equity Peak [$]                        115.12
# Return [%]                              10.98
# Buy & Hold Return [%]               -11.33829
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# CAGR [%]                  1058035078373143...
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              0.0
# Alpha [%]                              1.7785
# Beta                                 -0.81154
# Max. Drawdown [%]                     -5.9166
# Avg. Drawdown [%]                    -2.58323
# Max. Drawdown Duration        0 days 02:28:00
# Avg. Drawdown Duration        0 days 00:49:00
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# Kelly Criterion                           NaN
# _strategy                          MLStrategy
# _equity_curve                             ...
# _trades                   Empty DataFrame
# ...
# dtype: object
#   <div id="d99ab022-81e0-4fc1-ac0a-8177e2396227" data-root-id="p1393" style="display: contents;"></div>
# Pipeline complete.

# %% [markdown]
# ## Transformer

# %%
def build_transformer_model(input_shape):
    print("Building Transformer model with input shape:", input_shape)
    input_layer = Input(shape=input_shape)
    attention = MultiHeadAttention(num_heads=2, key_dim=input_shape[-1])(input_layer, input_layer)
    attention = Dropout(0.2)(attention)
    attention = LayerNormalization(epsilon=1e-6)(attention + input_layer)
    pooled = GlobalAveragePooling1D()(attention)
    dense = Dense(64, activation='relu')(pooled)
    output = Dense(1, activation='linear')(dense)
    model = Model(inputs=input_layer, outputs=output)
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
    return model

stats_btc_transformer = run_full_pipeline(asset="btc", model_type="transformer", data_percent=0.001)
# Out:
# Setting up directories...
# Loading data for asset: btc
# Subsetting data...
# Normalizing features...
# Creating sequences...
# Splitting data into training and testing sets...
# Building model...
# Building Transformer model with input shape: (30, 45)
# Training model...
# Epoch 1/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.8005
# Epoch 1: val_loss improved from inf to 0.33003, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 4s 6ms/step - loss: 0.7989 - val_loss: 0.3300
# Epoch 2/20
# 144/157 [==========================>...] - ETA: 0s - loss: 0.0348
# Epoch 2: val_loss improved from 0.33003 to 0.24913, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0340 - val_loss: 0.2491
# Epoch 3/20
# 148/157 [===========================>..] - ETA: 0s - loss: 0.0319
# Epoch 3: val_loss did not improve from 0.24913
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0315 - val_loss: 0.2637
# Epoch 4/20
# 149/157 [===========================>..] - ETA: 0s - loss: 0.0295
# Epoch 4: val_loss improved from 0.24913 to 0.19641, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0290 - val_loss: 0.1964
# Epoch 5/20
# 149/157 [===========================>..] - ETA: 0s - loss: 0.0242
# Epoch 5: val_loss improved from 0.19641 to 0.16465, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0237 - val_loss: 0.1646
# Epoch 6/20
# 150/157 [===========================>..] - ETA: 0s - loss: 0.0208
# Epoch 6: val_loss improved from 0.16465 to 0.13128, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0205 - val_loss: 0.1313
# Epoch 7/20
# 144/157 [==========================>...] - ETA: 0s - loss: 0.0193
# Epoch 7: val_loss did not improve from 0.13128
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0196 - val_loss: 0.1609
# Epoch 8/20
# 150/157 [===========================>..] - ETA: 0s - loss: 0.0189
# Epoch 8: val_loss improved from 0.13128 to 0.10686, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0188 - val_loss: 0.1069
# Epoch 9/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0187
# Epoch 9: val_loss did not improve from 0.10686
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0187 - val_loss: 0.1997
# Epoch 10/20
# 150/157 [===========================>..] - ETA: 0s - loss: 0.0179
# Epoch 10: val_loss did not improve from 0.10686
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0177 - val_loss: 0.1669
# Epoch 11/20
# 150/157 [===========================>..] - ETA: 0s - loss: 0.0170
# Epoch 11: val_loss did not improve from 0.10686
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0168 - val_loss: 0.1158
# Epoch 12/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0165
# Epoch 12: val_loss did not improve from 0.10686
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0164 - val_loss: 0.1321
# Epoch 13/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0159
# Epoch 13: val_loss did not improve from 0.10686
# Restoring model weights from the end of the best epoch: 8.
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0163 - val_loss: 0.1305
# Epoch 13: early stopping
# Plotting training loss...
# Loss curve saved to: plots/loss_curve_transformer_btc_0_1pct.png
# Generating predictions...
# 40/40 [==============================] - 0s 1ms/step
# Plotting predictions and saving comparison CSV...
# Prediction plot saved to: plots/prediction_plot_transformer_btc_0_1pct.png
# Comparison CSV saved to: data/result-data/btc_comparison_0_1pct.csv
# Printing evaluation metrics...
# Metrics for 0.100% dataset:
# MSE:  0.1069
# RMSE: 0.3269
# MAE:  0.3123
# Saving model and scaler...
# Model saved to: models/transformer_btc_model_0_1pct.h5
# Scaler saved to: models/scaler_btc_0_1pct.pkl
# Running backtesting...
# Backtest.run:   0%|          | 0/1250 [00:00<?, ?bar/s]
# Start                     2022-01-01 00:00:00
# End                       2022-01-01 20:50:00
# Duration                      0 days 20:50:00
# Exposure Time [%]                         0.0
# Equity Final [$]                        89.02
# Equity Peak [$]                        100.72
# Return [%]                             -10.98
# Buy & Hold Return [%]               -11.33829
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# CAGR [%]                               -100.0
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              0.0
# Alpha [%]                            -0.03545
# Beta                                  0.96527
# Max. Drawdown [%]                   -15.72677
# Avg. Drawdown [%]                    -4.47117
# Max. Drawdown Duration        0 days 17:34:00
# Avg. Drawdown Duration        0 days 03:56:00
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# Kelly Criterion                           NaN
# _strategy                          MLStrategy
# _equity_curve                             ...
# _trades                   Empty DataFrame
# ...
# dtype: object
#   <div id="d159e313-220f-4bc4-af8d-d4f6ab12890e" data-root-id="p1535" style="display: contents;"></div>
# Pipeline complete.

# %%
def build_rnn_model(input_shape):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import SimpleRNN, Dropout, Dense
    from tensorflow.keras.optimizers import Adam
    print("Building RNN model with input shape:", input_shape)
    model = Sequential()
    model.add(SimpleRNN(64, activation='tanh', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
    return model

# %%
stats_btc_transformer = run_full_pipeline(asset="btc", model_type="transformer", data_percent=0.001)
# Out:
# Setting up directories...
# Loading data for asset: btc
# Subsetting data...
# Normalizing features...
# Creating sequences...
# Splitting data into training and testing sets...
# Building model...
# Building Transformer model with input shape: (30, 45)
# Training model...
# Epoch 1/20
# 144/157 [==========================>...] - ETA: 0s - loss: 0.9944
# Epoch 1: val_loss improved from inf to 0.21663, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 3s 6ms/step - loss: 0.9203 - val_loss: 0.2166
# Epoch 2/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0347
# Epoch 2: val_loss did not improve from 0.21663
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0349 - val_loss: 0.2188
# Epoch 3/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0306
# Epoch 3: val_loss improved from 0.21663 to 0.14966, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.1497
# Epoch 4/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0293
# Epoch 4: val_loss did not improve from 0.14966
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0292 - val_loss: 0.1959
# Epoch 5/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0269
# Epoch 5: val_loss did not improve from 0.14966
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0267 - val_loss: 0.2002
# Epoch 6/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0274
# Epoch 6: val_loss did not improve from 0.14966
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0271 - val_loss: 0.1850
# Epoch 7/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0272
# Epoch 7: val_loss improved from 0.14966 to 0.13579, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0272 - val_loss: 0.1358
# Epoch 8/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0242
# Epoch 8: val_loss did not improve from 0.13579
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0243 - val_loss: 0.1621
# Epoch 9/20
# 154/157 [============================>.] - ETA: 0s - loss: 0.0238
# Epoch 9: val_loss did not improve from 0.13579
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0236 - val_loss: 0.2114
# Epoch 10/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0230
# Epoch 10: val_loss did not improve from 0.13579
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0228 - val_loss: 0.1363
# Epoch 11/20
# 153/157 [============================>.] - ETA: 0s - loss: 0.0219
# Epoch 11: val_loss improved from 0.13579 to 0.07395, saving model to models/gru_btc_model_0_1pct.h5
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0226 - val_loss: 0.0739
# Epoch 12/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0238
# Epoch 12: val_loss did not improve from 0.07395
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0235 - val_loss: 0.1254
# Epoch 13/20
# 154/157 [============================>.] - ETA: 0s - loss: 0.0218
# Epoch 13: val_loss did not improve from 0.07395
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0217 - val_loss: 0.1288
# Epoch 14/20
# 153/157 [============================>.] - ETA: 0s - loss: 0.0228
# Epoch 14: val_loss did not improve from 0.07395
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0226 - val_loss: 0.1107
# Epoch 15/20
# 152/157 [============================>.] - ETA: 0s - loss: 0.0201
# Epoch 15: val_loss did not improve from 0.07395
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0201 - val_loss: 0.1139
# Epoch 16/20
# 151/157 [===========================>..] - ETA: 0s - loss: 0.0180
# Epoch 16: val_loss did not improve from 0.07395
# Restoring model weights from the end of the best epoch: 11.
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0187 - val_loss: 0.1278
# Epoch 16: early stopping
# Plotting training loss...
# Loss curve saved to: plots/loss_curve_transformer_btc_0_1pct.png
# Generating predictions...
# 40/40 [==============================] - 0s 1ms/step
# Plotting predictions and saving comparison CSV...
# Prediction plot saved to: plots/prediction_plot_transformer_btc_0_1pct.png
# Comparison CSV saved to: data/result-data/btc_comparison_0_1pct.csv
# Printing evaluation metrics...
# Metrics for 0.100% dataset:
# MSE:  0.0739
# RMSE: 0.2719
# MAE:  0.2480
# Saving model and scaler...
# Model saved to: models/transformer_btc_model_0_1pct.h5
# Scaler saved to: models/scaler_btc_0_1pct.pkl
# Running backtesting...
# Backtest.run:   0%|          | 0/1250 [00:00<?, ?bar/s]
# Start                     2022-01-01 00:00:00
# End                       2022-01-01 20:50:00
# Duration                      0 days 20:50:00
# Exposure Time [%]                         0.0
# Equity Final [$]                        89.02
# Equity Peak [$]                        100.72
# Return [%]                             -10.98
# Buy & Hold Return [%]               -11.33829
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# CAGR [%]                               -100.0
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              0.0
# Alpha [%]                            -0.03545
# Beta                                  0.96527
# Max. Drawdown [%]                   -15.72677
# Avg. Drawdown [%]                    -4.47117
# Max. Drawdown Duration        0 days 17:34:00
# Avg. Drawdown Duration        0 days 03:56:00
# # Trades                                    0
# Win Rate [%]                              NaN
# Best Trade [%]                            NaN
# Worst Trade [%]                           NaN
# Avg. Trade [%]                            NaN
# Max. Trade Duration                       NaN
# Avg. Trade Duration                       NaN
# Profit Factor                             NaN
# Expectancy [%]                            NaN
# SQN                                       NaN
# Kelly Criterion                           NaN
# _strategy                          MLStrategy
# _equity_curve                             ...
# _trades                   Empty DataFrame
# ...
# dtype: object
#   <div id="a94228d1-fc5f-47e5-aca3-dce872b276db" data-root-id="p1677" style="display: contents;"></div>
# Pipeline complete.
